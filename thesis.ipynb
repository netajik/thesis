# %% [markdown]
# <a href="https://colab.research.google.com/github/netajik/thesis/blob/master/thesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install torch transformers einops scikit-learn matplotlib
# %pip install sae-lens  # optional, later
# %pip install ripser persim  # for topology (later)
